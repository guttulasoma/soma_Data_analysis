# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt

# %%
A=[23,45,67,89,10]   #corona cases in first five days
B=[1,2,3,4,5]
plt.plot(B,A)    #plot(x,y)
plt.show()

# %%
A=[23,45,67,89,10]   #corona cases in first five days
B=[1,2,3,4,5]
plt.plot(B,A,linestyle=":")    #:,.
plt.show()

# %% [markdown]
# 1.Runs scored by 10 new players[100,50,91,78,89,25,34,19,9,10] wickets taken by same 10 new players[1,0,2,0,3,7,8,9,7,5].Form clusters for batsmen and bowlers.

# %%
import numpy as np
runs=np.array([100,50,91,78,89,25,34,19,9,10])
wic=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,wic)
plt.show()

# %%
import numpy as np
runs=np.array([100,50,91,78,89,25,34,19,9,10])
wic=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,wic,color="pink")   #r,b,k,g,m,w,c,y,pink,orange...-colors
plt.show()

# %%
# Marker-D,d,p,H,s,+,X,x,,,0,*,h,v,^,<,>
import numpy as np
runs=np.array([100,50,91,78,89,25,34,19,9,10])
wic=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,wic,color="pink", marker="P")
plt.show()

# %% [markdown]
# Plot the Scores of 2 students in 5 different subjects . subjects as x axis and marks as y axis

# %%
Stu1=[56,78,92,95,78]
Stu2=[77,89,100,73,45]
sub=["maths","science","social","english","telugu"]
plt.plot(sub,Stu1,label="Student1")
plt.plot(sub,Stu2,label="Student2")
plt.legend()

# %%
#sub -plot
Stu1=[56,78,92,95,78]
Stu2=[77,89,100,73,45]
sub=["maths","science","social","english","telugu"]
plt.subplot(2,1,1)
plt.plot(sub,Stu1,label="Student1",color="m")
plt.legend()
plt.subplot(2,1,2)
plt.plot(sub,Stu2,label="Student2",color="b")
plt.legend()

# %% [markdown]
# Create Subplots(b←) showing the profits of two companies.
# year.       A     B
# 2019.   230   200
# 2020.   560   160
# 2021.   780   270
# 2022.   127   127
# 2023.   128   400

# %%
Com1=np.array([230,560,780,127,128])
Com2=np.array([200,160,270,127,400])
print("revenue of company ",Com1)
print("revenue of company ",Com2)
years=["19-20","20-21","21-22","22-23"]
profitA=np.diff(Com1)
print(profitA)
profitB=np.diff(Com2)
print(profitB)
plt.subplot(1,2,1)
plt.bar(years,profitA,label="Company1",color="k")
plt.legend(loc="best")
plt.subplot(1,2,2)
plt.bar(years,profitB,label="Company2",color="g")
plt.legend(loc="best")
plt.show()
# Out:
# revenue of company  [230 560 780 127 128]
# revenue of company  [200 160 270 127 400]
# [ 330  220 -653    1]
# [ -40  110 -143  273]

# %%
#piechart
a=np.array([25,60,5,10])
labe=["aiml","python","pandas","numpy"]
plt.pie(a,labels = labe)
plt.show()

# %%
#explode
a=np.array([25,60,5,10])
labe=["aiml","python","pandas","numpy"]
explo=[0.2,0,0,0]
plt.pie(a,labels = labe,explode = explo,startangle = 180)
plt.show()

# %%
#shadow
a=np.array([25,60,5,10])
labe=["aiml","python","pandas","numpy"]
explo=[0.3,0,0,0]
plt.pie(a,labels = labe,explode = explo,shadow = True)
plt.legend()
plt.show()
